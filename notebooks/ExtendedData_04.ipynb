# %% [markdown]
# ## Tables

# %%
import pandas as pd
from IPython.display import Image

# %%
results = pd.read_csv('../data/ExtendedData_04/results.csv', index_col=0)

# %% [markdown]
# In the table below the mAP comparison between CNN baseline ([HRNet](https://arxiv.org/abs/1908.07919)) and Transformer based models ([TokenPose](https://arxiv.org/abs/2104.03516) models and [ViTs](https://arxiv.org/abs/2010.11929)) on SuperAnimal-TopViewMouse and -Quadruped is presented. The performance of HRNet is comparable to performance shown in Extended Data, and here we used a different framework ([mmpose](https://github.com/open-mmlab/mmpose)), and transformers most-always outperformed HRNet. Suggesting that users also may consider other architectures when building SuperAnimal models.

# %%
results
# Out:
#            ViT-MAE  ViT-DeIT  TokenPose (HRNet)  TokenPose (CNN)  HRNet
# iRodent       26.6      28.2               40.7             39.5   40.3
# AwA-OOD       38.2      38.9               55.6             53.5   53.3
# TriMouse      32.4      34.2               33.4             43.5   28.1
# Openfield     63.6      62.4               91.5             82.7   72.3

# %%
params = pd.read_csv('../data/ExtendedData_04/complexity.csv', index_col=0)

# %% [markdown]
# In the table below the models complexity (number of parameters and multiply–accumulate operations) is shown.

# %%
params
# Out:
#                    Params, M  MACs, G
# ViT-MAE                29.80      7.5
# ViT-DeIT               15.00      8.8
# TokenPose (HRNet)       7.51     20.1
# TokenPose (CNN)        86.00     17.6
# HRNet                  86.00     17.6

# %% [markdown]
# ## Model architecture and tabels

# %%
model_architecture = Image(filename=('../data/ExtendedData_04/model_architecture.jpg'))

# %%
model_architecture
